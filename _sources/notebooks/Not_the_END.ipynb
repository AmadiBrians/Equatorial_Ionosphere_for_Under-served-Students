# %% [markdown]
# # Not the End...
# #### By Amadi Brians C.
# ##### bamadi@brianspace.org

# %% [markdown]
# - Thank you for reading.
#
# - This is not the end of this tutorial.
#
# - The complete package include four other short tutorials. They will be published once ready.
#
# - If you got questions, comments or inquiries, please feel free to drop your concern in the comment section.
#
# - Looking for mentorship, or guidance into space sciences and/or engineering, you are welcome to reach out via the form attached here.

# %% [raw]
# ## 💬 Comments
#
# <script src="https://giscus.app/client.js"
#         data-repo="AmadiBrians/Equatorial_Ionosphere_for_Under-served-Students"
#         data-repo-id="R_kgDOQLd0Rw"
#         data-category="General"
#         data-category-id="DIC_kwDOQLd0R84CxN0d"
#         data-mapping="pathname"
#         data-strict="0"
#         data-reactions-enabled="1"
#         data-emit-metadata="0"
#         data-input-position="bottom"
#         data-theme="preferred_color_scheme"
#         data-lang="en"
#         crossorigin="anonymous"
#         async>
# </script>
